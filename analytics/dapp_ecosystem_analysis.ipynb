# %% [markdown]
# # DApp Ecosystem Analysis
# ## Comprehensive Analysis of 855 Decentralized Applications
#
# **Dataset**: DAPP_Dataset_Nov_2025 - Final.csv
# **DApps**: 855
# **Variables**: 33 original + 15 derived = 48 total
# **Blockchains**: 77 unique chains
#
# This notebook provides an interactive exploration of the DApp ecosystem through 9 comprehensive analyses.

# %%
# Setup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from config import RAW_DATA_PATH, DATA_PATH, OUTPUT_DIR

plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

print("✓ Environment ready")
print(f"  Raw data:  {RAW_DATA_PATH}")
print(f"  Prepared:  {DATA_PATH}")
print(f"  Outputs:   {OUTPUT_DIR}")
print("\\nTo run all analyses, execute each cell in order.")
print("\\nOr run individual analysis scripts:")
print("  %run 01_data_preparation.py")
print("  %run 02_governance_analysis.py")
print("  ... etc")

# %% [markdown]
# ## 8 Key Insights Summary
#
# 1. **Governance Centralization Paradox**: Only 5.2% truly decentralized
# 2. **Chain Ecosystem Specialization**: Different blockchains serve distinct niches
# 3. **Extreme Market Concentration**: Top 10 DApps control 57.5% of market cap
# 4. **Engagement Dichotomy**: Gaming = high users/low value; DeFi = low users/high value
# 5. **TVL Efficiency Gap**: Top 10 DApps control 93.1% of TVL
# 6. **Funding Paradox**: Weak correlation between capital raised and success
# 7. **Multi-Chain Premium**: Cross-chain DApps command 1.3x higher valuations
# 8. **Governance-Performance Link**: More decentralized → better performance
#
# ---
#
# **To run full analysis**: Execute `./run_all_analyses.sh` from analytics folder
#
# **Results**: All outputs saved to `outputs/` directory
#
# See `09_KEY_INSIGHTS.txt` and `ANALYSIS_SUMMARY.md` for detailed findings.
